# %%
import pandas as pd

# %%
df = pd.read_csv('D:\BCA- STUDY\Python\Datasets\Book2.csv')
df
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN
# 4   5        Techdrill                 NaN   3138627     8%

# %%
df.dropna()
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%

# %%
df.dropna(axis=1)
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  11412916
# 2   3   3005820
# 3   4   6597557
# 4   5   3138627

# %%
df.dropna(how='any')
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%

# %%
df.dropna(axis=1, how='any')
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  11412916
# 2   3   3005820
# 3   4   6597557
# 4   5   3138627

# %%
df = pd.read_csv('D:\BCA- STUDY\Python\Datasets\Book2.csv')
df
# Out:
#     ID             Name            Industry      Profit  Growth
# 0  1.0          Lamtone         IT Services   5274553.0     NaN
# 1  2.0        Stripfind  Financial Services  11412916.0     NaN
# 2  3.0  Canecorporation              Health   3005820.0     NaN
# 3  4.0              NaN         IT Services   6597557.0     NaN
# 4  NaN              NaN                 NaN         NaN     NaN

# %%
df.dropna(how='all')
# Out:
#     ID             Name            Industry      Profit  Growth
# 0  1.0          Lamtone         IT Services   5274553.0     NaN
# 1  2.0        Stripfind  Financial Services  11412916.0     NaN
# 2  3.0  Canecorporation              Health   3005820.0     NaN
# 3  4.0              NaN         IT Services   6597557.0     NaN

# %%
df.dropna(axis=1, how='all')
# Out:
#     ID             Name            Industry      Profit
# 0  1.0          Lamtone         IT Services   5274553.0
# 1  2.0        Stripfind  Financial Services  11412916.0
# 2  3.0  Canecorporation              Health   3005820.0
# 3  4.0              NaN         IT Services   6597557.0
# 4  NaN              NaN                 NaN         NaN

# %%
df.dropna(thresh=2)
# Out:
#     ID             Name            Industry      Profit  Growth
# 0  1.0          Lamtone         IT Services   5274553.0     NaN
# 1  2.0        Stripfind  Financial Services  11412916.0     NaN
# 2  3.0  Canecorporation              Health   3005820.0     NaN
# 3  4.0              NaN         IT Services   6597557.0     NaN

# %%
df.dropna(axis=1, thresh=2)
# Out:
#     ID             Name            Industry      Profit
# 0  1.0          Lamtone         IT Services   5274553.0
# 1  2.0        Stripfind  Financial Services  11412916.0
# 2  3.0  Canecorporation              Health   3005820.0
# 3  4.0              NaN         IT Services   6597557.0
# 4  NaN              NaN                 NaN         NaN

# %%
df.dropna(subset=['Profit'])
# Out:
#     ID             Name            Industry      Profit  Growth
# 0  1.0          Lamtone         IT Services   5274553.0     NaN
# 1  2.0        Stripfind  Financial Services  11412916.0     NaN
# 2  3.0  Canecorporation              Health   3005820.0     NaN
# 3  4.0              NaN         IT Services   6597557.0     NaN

# %%
df.dropna(subset=['Profit','Name'])
# Out:
#     ID             Name            Industry      Profit  Growth
# 0  1.0          Lamtone         IT Services   5274553.0     NaN
# 1  2.0        Stripfind  Financial Services  11412916.0     NaN
# 2  3.0  Canecorporation              Health   3005820.0     NaN

# %%
df.dropna(subset=['Growth'])
# Out:
# Empty DataFrame
# Columns: [ID, Name, Industry, Profit, Growth]
# Index: []
