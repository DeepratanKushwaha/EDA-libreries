# %%
import pandas as pd

# %%
pd.read_csv('D:\\BCA- STUDY\\Python\Datasets\\international-migration-September-2020-.csv')
# Out:
#       year_month month_of_release     passenger_type direction     sex  \
# 0        2019-05          2020-09  Long-term migrant  Arrivals  Female
# 1        2019-06          2020-09  Long-term migrant  Arrivals  Female
# 2        2019-07          2020-09  Long-term migrant  Arrivals  Female
# 3        2019-08          2020-09  Long-term migrant  Arrivals  Female
# 4        2019-09          2020-09  Long-term migrant  Arrivals  Female
# ...          ...              ...                ...       ...     ...
# 42180    2018-12          2020-09  Long-term migrant       Net   TOTAL
# 42181    2019-01          2020-09  Long-term migrant       Net   TOTAL
# 42182    2019-02          2020-09  Long-term migrant       Net   TOTAL
# 42183    2019-03          2020-09  Long-term migrant       Net   TOTAL
# 42184    2019-04          2020-09  Long-term migrant       Net   TOTAL
#
#              age  estimate  standard_error       status
# 0      0-4 years       316               0        Final
# ...

# %%
pd.read_csv('D:\\BCA- STUDY\\Python\Datasets\\international-migration-September-2020-.csv', header = 1)
# Out:
#        2019-05  2020-09  Long-term migrant  Arrivals  Female  0-4 years   316  \
# 0      2019-06  2020-09  Long-term migrant  Arrivals  Female  0-4 years   340
# 1      2019-07  2020-09  Long-term migrant  Arrivals  Female  0-4 years   357
# 2      2019-08  2020-09  Long-term migrant  Arrivals  Female  0-4 years   421
# 3      2019-09  2020-09  Long-term migrant  Arrivals  Female  0-4 years   396
# 4      2019-10  2020-09  Long-term migrant  Arrivals  Female  0-4 years   382
# ...        ...      ...                ...       ...     ...        ...   ...
# 42179  2018-12  2020-09  Long-term migrant       Net   TOTAL      TOTAL  3141
# 42180  2019-01  2020-09  Long-term migrant       Net   TOTAL      TOTAL  6326
# 42181  2019-02  2020-09  Long-term migrant       Net   TOTAL      TOTAL  6786
# 42182  2019-03  2020-09  Long-term migrant       Net   TOTAL      TOTAL  3543
# 42183  2019-04  2020-09  Long-term migrant       Net   TOTAL      TOTAL  1857
#
#        0        Final
# ...

# %%
pd.read_csv('D:\\BCA- STUDY\\Python\Datasets\\international-migration-September-2020-.csv')
# Out:
#                 0                 1                  2          3       4  \
# 0      year_month  month_of_release     passenger_type  direction     sex
# 1         2019-05           2020-09  Long-term migrant   Arrivals  Female
# 2         2019-06           2020-09  Long-term migrant   Arrivals  Female
# 3         2019-07           2020-09  Long-term migrant   Arrivals  Female
# 4         2019-08           2020-09  Long-term migrant   Arrivals  Female
# ...           ...               ...                ...        ...     ...
# 42181     2018-12           2020-09  Long-term migrant        Net   TOTAL
# 42182     2019-01           2020-09  Long-term migrant        Net   TOTAL
# 42183     2019-02           2020-09  Long-term migrant        Net   TOTAL
# 42184     2019-03           2020-09  Long-term migrant        Net   TOTAL
# 42185     2019-04           2020-09  Long-term migrant        Net   TOTAL
#
#                5         6               7            8
# ...

# %%
pd.read_csv('D:\\BCA- STUDY\\Python\Datasets\\international-migration-September-2020-.csv', header = 1)
# Out:
#       year_month month_of_release     passenger_type direction     sex  \
# 0        2019-05          2020-09  Long-term migrant  Arrivals  Female
# 1        2019-06          2020-09  Long-term migrant  Arrivals  Female
# 2        2019-07          2020-09  Long-term migrant  Arrivals  Female
# 3        2019-08          2020-09  Long-term migrant  Arrivals  Female
# 4        2019-09          2020-09  Long-term migrant  Arrivals  Female
# ...          ...              ...                ...       ...     ...
# 42180    2018-12          2020-09  Long-term migrant       Net   TOTAL
# 42181    2019-01          2020-09  Long-term migrant       Net   TOTAL
# 42182    2019-02          2020-09  Long-term migrant       Net   TOTAL
# 42183    2019-03          2020-09  Long-term migrant       Net   TOTAL
# 42184    2019-04          2020-09  Long-term migrant       Net   TOTAL
#
#              age  estimate  standard_error       status
# 0      0-4 years       316               0        Final
# ...

# %%
pd.read_csv('D:\\BCA- STUDY\\Python\Datasets\\international-migration-September-2020-.csv')
# Out:
#        Unnamed: 0              data         Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0               0                 1                  2          3          4
# 1      year_month  month_of_release     passenger_type  direction        sex
# 2         2019-05           2020-09  Long-term migrant   Arrivals     Female
# 3         2019-06           2020-09  Long-term migrant   Arrivals     Female
# 4         2019-07           2020-09  Long-term migrant   Arrivals     Female
# ...           ...               ...                ...        ...        ...
# 42182     2018-12           2020-09  Long-term migrant        Net      TOTAL
# 42183     2019-01           2020-09  Long-term migrant        Net      TOTAL
# 42184     2019-02           2020-09  Long-term migrant        Net      TOTAL
# 42185     2019-03           2020-09  Long-term migrant        Net      TOTAL
# 42186     2019-04           2020-09  Long-term migrant        Net      TOTAL
#
# ...

# %%
pd.read_csv('D:\\BCA- STUDY\\Python\Datasets\\international-migration-September-2020-.csv', header = 2)
# Out:
#       year_month month_of_release     passenger_type direction     sex  \
# 0        2019-05          2020-09  Long-term migrant  Arrivals  Female
# 1        2019-06          2020-09  Long-term migrant  Arrivals  Female
# 2        2019-07          2020-09  Long-term migrant  Arrivals  Female
# 3        2019-08          2020-09  Long-term migrant  Arrivals  Female
# 4        2019-09          2020-09  Long-term migrant  Arrivals  Female
# ...          ...              ...                ...       ...     ...
# 42180    2018-12          2020-09  Long-term migrant       Net   TOTAL
# 42181    2019-01          2020-09  Long-term migrant       Net   TOTAL
# 42182    2019-02          2020-09  Long-term migrant       Net   TOTAL
# 42183    2019-03          2020-09  Long-term migrant       Net   TOTAL
# 42184    2019-04          2020-09  Long-term migrant       Net   TOTAL
#
#              age  estimate  standard_error       status
# 0      0-4 years       316               0        Final
# ...

# %%
pd.read_csv('D:\\BCA- STUDY\\Python\Datasets\\international-migration-September-2020-.csv')
# Out:
#        2019-05  2020-09  Long-term migrant  Arrivals  Female  0-4 years   316  \
# 0      2019-06  2020-09  Long-term migrant  Arrivals  Female  0-4 years   340
# 1      2019-07  2020-09  Long-term migrant  Arrivals  Female  0-4 years   357
# 2      2019-08  2020-09  Long-term migrant  Arrivals  Female  0-4 years   421
# 3      2019-09  2020-09  Long-term migrant  Arrivals  Female  0-4 years   396
# 4      2019-10  2020-09  Long-term migrant  Arrivals  Female  0-4 years   382
# ...        ...      ...                ...       ...     ...        ...   ...
# 42179  2018-12  2020-09  Long-term migrant       Net   TOTAL      TOTAL  3141
# 42180  2019-01  2020-09  Long-term migrant       Net   TOTAL      TOTAL  6326
# 42181  2019-02  2020-09  Long-term migrant       Net   TOTAL      TOTAL  6786
# 42182  2019-03  2020-09  Long-term migrant       Net   TOTAL      TOTAL  3543
# 42183  2019-04  2020-09  Long-term migrant       Net   TOTAL      TOTAL  1857
#
#        0        Final
# ...

# %%
pd.read_csv('D:\\BCA- STUDY\\Python\Datasets\\international-migration-September-2020-.csv', names = ['year_month','month_of_release','passenger_type','direction','sex','age','estimate','standard_error','status'])
# Out:
#       year_month month_of_release     passenger_type direction     sex  \
# 0        2019-05          2020-09  Long-term migrant  Arrivals  Female
# 1        2019-06          2020-09  Long-term migrant  Arrivals  Female
# 2        2019-07          2020-09  Long-term migrant  Arrivals  Female
# 3        2019-08          2020-09  Long-term migrant  Arrivals  Female
# 4        2019-09          2020-09  Long-term migrant  Arrivals  Female
# ...          ...              ...                ...       ...     ...
# 42180    2018-12          2020-09  Long-term migrant       Net   TOTAL
# 42181    2019-01          2020-09  Long-term migrant       Net   TOTAL
# 42182    2019-02          2020-09  Long-term migrant       Net   TOTAL
# 42183    2019-03          2020-09  Long-term migrant       Net   TOTAL
# 42184    2019-04          2020-09  Long-term migrant       Net   TOTAL
#
#              age  estimate  standard_error       status
# 0      0-4 years       316               0        Final
# ...
