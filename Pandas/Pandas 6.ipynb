# %% [markdown]
# # write csv file in pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\BCA- STUDY\\Python\\Datasets\\international-migration-September-2020-.csv')
df
# Out:
#       year_month year_month.1       year_month.2 year_month.3 year_month.4  \
# 0        2019-05      2020-09  Long-term migrant     Arrivals       Female
# 1        2019-06      2020-09  Long-term migrant     Arrivals       Female
# 2        2019-07      2020-09  Long-term migrant     Arrivals       Female
# 3        2019-08      2020-09  Long-term migrant     Arrivals       Female
# 4        2019-09      2020-09  Long-term migrant     Arrivals       Female
# ...          ...          ...                ...          ...          ...
# 42180    2018-12      2020-09  Long-term migrant          Net        TOTAL
# 42181    2019-01      2020-09  Long-term migrant          Net        TOTAL
# 42182    2019-02      2020-09  Long-term migrant          Net        TOTAL
# 42183    2019-03      2020-09  Long-term migrant          Net        TOTAL
# 42184    2019-04      2020-09  Long-term migrant          Net        TOTAL
#
#       year_month.5  year_month.6  year_month.7 year_month.8
# ...

# %%
df.head()
# Out:
#   year_month year_month.1       year_month.2 year_month.3 year_month.4  \
# 0    2019-05      2020-09  Long-term migrant     Arrivals       Female
# 1    2019-06      2020-09  Long-term migrant     Arrivals       Female
# 2    2019-07      2020-09  Long-term migrant     Arrivals       Female
# 3    2019-08      2020-09  Long-term migrant     Arrivals       Female
# 4    2019-09      2020-09  Long-term migrant     Arrivals       Female
#
#   year_month.5  year_month.6  year_month.7 year_month.8
# 0    0-4 years           316             0        Final
# 1    0-4 years           340             0  Provisional
# 2    0-4 years           357             1  Provisional
# 3    0-4 years           421             2  Provisional
# 4    0-4 years           396             3  Provisional

# %%
df.head(1)
# Out:
#   year_month year_month.1       year_month.2 year_month.3 year_month.4  \
# 0    2019-05      2020-09  Long-term migrant     Arrivals       Female
#
#   year_month.5  year_month.6  year_month.7 year_month.8
# 0    0-4 years           316             0        Final

# %%
df.head(8)
# Out:
#   year_month year_month.1       year_month.2 year_month.3 year_month.4  \
# 0    2019-05      2020-09  Long-term migrant     Arrivals       Female
# 1    2019-06      2020-09  Long-term migrant     Arrivals       Female
# 2    2019-07      2020-09  Long-term migrant     Arrivals       Female
# 3    2019-08      2020-09  Long-term migrant     Arrivals       Female
# 4    2019-09      2020-09  Long-term migrant     Arrivals       Female
# 5    2019-10      2020-09  Long-term migrant     Arrivals       Female
# 6    2019-11      2020-09  Long-term migrant     Arrivals       Female
# 7    2019-12      2020-09  Long-term migrant     Arrivals       Female
#
#   year_month.5  year_month.6  year_month.7 year_month.8
# 0    0-4 years           316             0        Final
# 1    0-4 years           340             0  Provisional
# 2    0-4 years           357             1  Provisional
# 3    0-4 years           421             2  Provisional
# ...

# %%
df.tail()
# Out:
#       year_month year_month.1       year_month.2 year_month.3 year_month.4  \
# 42180    2018-12      2020-09  Long-term migrant          Net        TOTAL
# 42181    2019-01      2020-09  Long-term migrant          Net        TOTAL
# 42182    2019-02      2020-09  Long-term migrant          Net        TOTAL
# 42183    2019-03      2020-09  Long-term migrant          Net        TOTAL
# 42184    2019-04      2020-09  Long-term migrant          Net        TOTAL
#
#       year_month.5  year_month.6  year_month.7 year_month.8
# 42180        TOTAL          3141             0        Final
# 42181        TOTAL          6326             0        Final
# 42182        TOTAL          6786             0        Final
# 42183        TOTAL          3543             0        Final
# 42184        TOTAL          1857             0        Final

# %%
df.tail(2)
# Out:
#       year_month year_month.1       year_month.2 year_month.3 year_month.4  \
# 42183    2019-03      2020-09  Long-term migrant          Net        TOTAL
# 42184    2019-04      2020-09  Long-term migrant          Net        TOTAL
#
#       year_month.5  year_month.6  year_month.7 year_month.8
# 42183        TOTAL          3543             0        Final
# 42184        TOTAL          1857             0        Final

# %%
df.tail(10)
# Out:
#       year_month year_month.1       year_month.2 year_month.3 year_month.4  \
# 42175    2018-07      2020-09  Long-term migrant          Net        TOTAL
# 42176    2018-08      2020-09  Long-term migrant          Net        TOTAL
# 42177    2018-09      2020-09  Long-term migrant          Net        TOTAL
# 42178    2018-10      2020-09  Long-term migrant          Net        TOTAL
# 42179    2018-11      2020-09  Long-term migrant          Net        TOTAL
# 42180    2018-12      2020-09  Long-term migrant          Net        TOTAL
# 42181    2019-01      2020-09  Long-term migrant          Net        TOTAL
# 42182    2019-02      2020-09  Long-term migrant          Net        TOTAL
# 42183    2019-03      2020-09  Long-term migrant          Net        TOTAL
# 42184    2019-04      2020-09  Long-term migrant          Net        TOTAL
#
#       year_month.5  year_month.6  year_month.7 year_month.8
# 42175        TOTAL          4700             0        Final
# ...

# %%
df = pd.read_csv('D:\\BCA- STUDY\\Python\\Datasets\\international-migration-September-2020-.csv', dtype={'year_month.7':'float64' })
df
# Out:
#       year_month year_month.1       year_month.2 year_month.3 year_month.4  \
# 0        2019-05      2020-09  Long-term migrant     Arrivals       Female
# 1        2019-06      2020-09  Long-term migrant     Arrivals       Female
# 2        2019-07      2020-09  Long-term migrant     Arrivals       Female
# 3        2019-08      2020-09  Long-term migrant     Arrivals       Female
# 4        2019-09      2020-09  Long-term migrant     Arrivals       Female
# ...          ...          ...                ...          ...          ...
# 42180    2018-12      2020-09  Long-term migrant          Net        TOTAL
# 42181    2019-01      2020-09  Long-term migrant          Net        TOTAL
# 42182    2019-02      2020-09  Long-term migrant          Net        TOTAL
# 42183    2019-03      2020-09  Long-term migrant          Net        TOTAL
# 42184    2019-04      2020-09  Long-term migrant          Net        TOTAL
#
#       year_month.5  year_month.6  year_month.7 year_month.8
# ...

# %%
df = pd.read_csv('D:\\BCA- STUDY\\Python\\Datasets\\international-migration-September-2020-.csv ', dtype={'year_month.7':'float64','year_month.6':'float64'})
df
# Out:
#       year_month year_month.1       year_month.2 year_month.3 year_month.4  \
# 0        2019-05      2020-09  Long-term migrant     Arrivals       Female
# 1        2019-06      2020-09  Long-term migrant     Arrivals       Female
# 2        2019-07      2020-09  Long-term migrant     Arrivals       Female
# 3        2019-08      2020-09  Long-term migrant     Arrivals       Female
# 4        2019-09      2020-09  Long-term migrant     Arrivals       Female
# ...          ...          ...                ...          ...          ...
# 42180    2018-12      2020-09  Long-term migrant          Net        TOTAL
# 42181    2019-01      2020-09  Long-term migrant          Net        TOTAL
# 42182    2019-02      2020-09  Long-term migrant          Net        TOTAL
# 42183    2019-03      2020-09  Long-term migrant          Net        TOTAL
# 42184    2019-04      2020-09  Long-term migrant          Net        TOTAL
#
#       year_month.5  year_month.6  year_month.7 year_month.8
# ...

# %%
df = pd.read_csv('D:\\BCA- STUDY\\Python\\Datasets\\international-migration-September-2020-.csv')
df
# Out:
#       year_month data year_month.1       year_month.2 year_month.3  \
# 0        2019-05  yes      2020-09  Long-term migrant     Arrivals
# 1        2019-06  yes      2020-09  Long-term migrant     Arrivals
# 2        2019-07  yes      2020-09  Long-term migrant     Arrivals
# 3        2019-08  yes      2020-09  Long-term migrant     Arrivals
# 4        2019-09  yes      2020-09  Long-term migrant     Arrivals
# ...          ...  ...          ...                ...          ...
# 42180    2018-12  NaN      2020-09  Long-term migrant          Net
# 42181    2019-01  NaN      2020-09  Long-term migrant          Net
# 42182    2019-02  NaN      2020-09  Long-term migrant          Net
# 42183    2019-03  NaN      2020-09  Long-term migrant          Net
# 42184    2019-04  NaN      2020-09  Long-term migrant          Net
#
#       year_month.4 year_month.5  year_month.6  year_month.7 year_month.8
# 0           Female    0-4 years           316             0        Final
# ...

# %%
df = pd.read_csv('D:\\BCA- STUDY\\Python\\Datasets\\international-migration-September-2020-.csv', false_values = ['no'], true_values = ['yes'])
df
# Out:
#       year_month   data year_month.1       year_month.2 year_month.3  \
# 0        2019-05   True      2020-09  Long-term migrant     Arrivals
# 1        2019-06   True      2020-09  Long-term migrant     Arrivals
# 2        2019-07  False      2020-09  Long-term migrant     Arrivals
# 3        2019-08   True      2020-09  Long-term migrant     Arrivals
# 4        2019-09   True      2020-09  Long-term migrant     Arrivals
# ...          ...    ...          ...                ...          ...
# 42180    2018-12    NaN      2020-09  Long-term migrant          Net
# 42181    2019-01    NaN      2020-09  Long-term migrant          Net
# 42182    2019-02    NaN      2020-09  Long-term migrant          Net
# 42183    2019-03    NaN      2020-09  Long-term migrant          Net
# 42184    2019-04    NaN      2020-09  Long-term migrant          Net
#
#       year_month.4 year_month.5  year_month.6  year_month.7 year_month.8
# ...
