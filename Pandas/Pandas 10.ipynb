# %%
import pandas as pd

# %%
df = pd.read_csv('D:\BCA- STUDY\Python\Datasets\Book2.csv')
df
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN
# 4   5        Techdrill                 NaN   3138627     8%

# %%
df.fillna(value=9)
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4                9         IT Services   6597557      9
# 4   5        Techdrill                   9   3138627     8%

# %%
df.fillna({'Name':'Scofild', 'Industry':'Hospital', 'Growth':'12%'})
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4          Scofild         IT Services   6597557    12%
# 4   5        Techdrill            Hospital   3138627     8%

# %%
df.fillna({'Name':'Scofild', 'Industry':'Hospital', 'Growth':'12%'})
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4          Scofild         IT Services   6597557    12%
# 4   5        Techdrill            Hospital   3138627     8%

# %%
df.fillna(method='ffill')
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4  Canecorporation         IT Services   6597557     7%
# 4   5        Techdrill         IT Services   3138627     8%

# %%
df.fillna(method='pad')
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4  Canecorporation         IT Services   6597557     7%
# 4   5        Techdrill         IT Services   3138627     8%

# %%
df.fillna(method='bfill')
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4        Techdrill         IT Services   6597557     8%
# 4   5        Techdrill                 NaN   3138627     8%

# %%
df.fillna(method='backfill')
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4        Techdrill         IT Services   6597557     8%
# 4   5        Techdrill                 NaN   3138627     8%

# %%
df.fillna(method='ffill', axis=0)
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4  Canecorporation         IT Services   6597557     7%
# 4   5        Techdrill         IT Services   3138627     8%

# %%
df.fillna(method='ffill', axis=1)
# Out:
#   ID             Name            Industry    Profit   Growth
# 0  1          Lamtone         IT Services   5274553      30%
# 1  2        Stripfind  Financial Services  11412916      20%
# 2  3  Canecorporation              Health   3005820       7%
# 3  4                4         IT Services   6597557  6597557
# 4  5        Techdrill           Techdrill   3138627       8%

# %%
df.fillna(method='bfill', axis=0)
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4        Techdrill         IT Services   6597557     8%
# 4   5        Techdrill                 NaN   3138627     8%

# %%
df.fillna(method='bfill', axis=1)
# Out:
#   ID             Name            Industry    Profit Growth
# 0  1          Lamtone         IT Services   5274553    30%
# 1  2        Stripfind  Financial Services  11412916    20%
# 2  3  Canecorporation              Health   3005820     7%
# 3  4      IT Services         IT Services   6597557    NaN
# 4  5        Techdrill             3138627   3138627     8%

# %%
df.fillna(500, limit=1)
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              500         IT Services   6597557    500
# 4   5        Techdrill                 500   3138627     8%

# %%
df.fillna(5, limit=1)
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4                5         IT Services   6597557      5
# 4   5        Techdrill                   5   3138627     8%

# %%
df.fillna(method='ffill', limit=2)
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4  Canecorporation         IT Services   6597557     7%
# 4   5        Techdrill         IT Services   3138627     8%

# %%
df.fillna(method='bfill',limit=2)
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4        Techdrill         IT Services   6597557     8%
# 4   5        Techdrill                 NaN   3138627     8%

# %%
df.fillna(5, inplace=True)
df
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4                5         IT Services   6597557      5
# 4   5        Techdrill                   5   3138627     8%

# %%
df.fillna(5, inplace=False)
df
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4                5         IT Services   6597557      5
# 4   5        Techdrill                   5   3138627     8%
