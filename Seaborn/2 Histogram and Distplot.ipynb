# %%
import seaborn as sns
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(df['size'])

# %%
sns.distplot(df['tip'])

# %%
sns.distplot(df['total_bill'])

# %%
sns.distplot(df['total_bill'], bins=50)

# %%
sns.distplot(df['total_bill'], bins=[15,25,35,60,70])

# %%
sns.distplot(df['total_bill'], bins=50, hist=False)

# %%
sns.distplot(df['total_bill'], bins=50, hist=True, kde=False)

# %%
sns.distplot(df['total_bill'], rug=True)

# %%
sns.distplot(df['total_bill'], fit=norm)

# %%
sns.distplot(df['total_bill'], fit=norm, kde=Flase)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-615463811aa0> in <module>
# ----> 1 sns.distplot(df['total_bill'], fit=norm, kde=Flase)
#
# NameError: name 'Flase' is not defined

# %%
sns.distplot(df['total_bill'], color='y')

# %%
sns.distplot(df['total_bill'], vertical=True)

# %%
sns.distplot(df['total_bill'], axlabel='Bill')

# %%
sns.distplot(df['total_bill'], label='Total_Bill')
plt.title('Histogram of total bill')
plt.legend()

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(df['total_bill'], label='Total_Bill')
plt.title('Histogram of total bill')
plt.legend()

# %%
df.total_bill.sort_values()
# Out:
# 67      3.07
# 92      5.75
# 111     7.25
# 172     7.25
# 149     7.51
#        ...
# 182    45.35
# 156    48.17
# 59     48.27
# 212    48.33
# 170    50.81
# Name: total_bill, Length: 244, dtype: float64

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50]
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(df['total_bill'], bins)
plt.xticks(bins)

plt.title('Histogram of total bill')
plt.legend()  
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(df['total_bill'], hist_kws={'color':'#DC143C', 'edgecolor':'#aaff00', 'linewidth':5, 'linestyle':'--', 
                                         'alpha':0.9})
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(df['total_bill'], hist_kws={'color':'#DC143C', 'edgecolor':'#aaff00', 'linewidth':5, 'linestyle':'--', 
                                         'alpha':0.9}, kde_kws={'color':'#8e00ce', 'linewidth':6, 
                                                                'linestyle':'--', 'alpha':0.9})
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(df['total_bill'], 
             hist_kws={'color':'#DC143C', 'edgecolor':'#aaff00', 'linewidth':5, 'linestyle':'--', 'alpha':0.9}, 
             kde_kws={'color':'#8e00ce', 'linewidth':6, 'linestyle':'--', 'alpha':0.9}, 
             rug=True, 
             rug_kws={'color':'#0426d0', 'edgecolor':'#00dbff', 'linewidth':2, 'linestyle':'--', 'alpha':0.9})
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(df['total_bill'], 
             hist_kws={'color':'#DC143C', 'edgecolor':'#aaff00', 'linewidth':5, 'linestyle':'--', 'alpha':0.9}, 
             kde=False,
             fit=norm,
             fit_kws={'color':'#8e00ce', 'linewidth':12, 'linestyle':'--', 'alpha':0.5}, 
             rug=True, 
             rug_kws={'color':'#0426d0', 'edgecolor':'#00dbff', 'linewidth':2, 'linestyle':'--', 'alpha':0.9})
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(df['total_bill'], 
             hist_kws={'color':'#DC143C', 'edgecolor':'#aaff00', 'linewidth':5, 'linestyle':'--', 'alpha':0.9}, 
             kde=False,
             fit=norm,
             fit_kws={'color':'#8e00ce', 'linewidth':12, 'linestyle':'--', 'alpha':0.5}, 
             rug=True, 
             rug_kws={'color':'#0426d0', 'edgecolor':'#00dbff', 'linewidth':2, 'linestyle':'--', 'alpha':0.9}, 
             label='Tb')
plt.title('Histogram of restaurent total bill')
plt.xlabel('total bill', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.distplot(df['total_bill'], bins=9, label='total_bill')
sns.distplot(df['tip'], bins=9, label='tip')
sns.distplot(df['size'], bins=9, label='size')
plt.legend()
